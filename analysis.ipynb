# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('clean_data.csv')
data
# Out:
#        index    food_category food_department     food_family  store_sales  \
# 0          0  Breakfast Foods    Frozen Foods            Food         7.36
# 1          1  Breakfast Foods    Frozen Foods            Food         5.52
# 2          2  Breakfast Foods    Frozen Foods            Food         3.68
# 3          3  Breakfast Foods    Frozen Foods            Food         3.68
# 4          4  Breakfast Foods    Frozen Foods            Food         4.08
# ...      ...              ...             ...             ...          ...
# 60423  60423        Specialty        Carousel  Non-Consumable         2.76
# 60424  60424        Specialty        Carousel  Non-Consumable         1.60
# 60425  60425        Specialty        Carousel  Non-Consumable         5.52
# 60426  60426        Specialty        Carousel  Non-Consumable         8.28
# 60427  60427        Specialty        Carousel  Non-Consumable         9.20
#
# ...

# %%
data = data.drop('index', axis=1)

# %%
data.columns
# Out:
# Index(['food_category', 'food_department', 'food_family', 'store_sales',
#        'store_cost', 'unit_sales', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at_home',
#        'avg_yearly_income', 'num_children_at_home', 'avg_cars_at_home1',
#        'brand_name', 'SRP', 'gross_weight', 'net_weight', 'recyclable_package',
#        'low_fat', 'units_per_case', 'store_type', 'store_city', 'store_state',
#        'store_sqft', 'grocery_sqft', 'frozen_sqft', 'meat_sqft', 'coffee_bar',
#        'video_store', 'salad_bar', 'prepared_food', 'florist', 'media_type',
#        'cost'],
#       dtype='object')

# %%
sns.set_style('darkgrid')

# %%
fig = plt.figure(figsize=(12,12))
sns.countplot(data=data, y='food_category', color='crimson')
fig.show()

# %%
fig = plt.figure(figsize=(12,10))
sns.countplot(data=data, y='food_department', palette='rainbow')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='food_family', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='store_sales', kde=True, color='#1ABC9C')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='store_cost', kde=True, color='#C832D6')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='unit_sales', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(12,15))
sns.countplot(data=data, y='promotion_name', color='black')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='sales_country', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='marital_status', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='gender', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='total_children', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='education', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='member_card', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='occupation', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='houseowner', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='avg_cars_at_home', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='num_children_at_home', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=data, x='avg_cars_at_home1', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(15,25))
sns.countplot(data=data, y='brand_name', color='palevioletred')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='SRP', kde=True, color='#34495E')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='gross_weight', kde=True, color='#F39C12')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='net_weight', kde=True, color='crimson')
fig.show()

# %%
fig = plt.figure(figsize=(10,5))
sns.countplot(data=data, x='recyclable_package', palette='rocket')
fig.show()

# %%
fig = plt.figure(figsize=(10,5))
sns.countplot(data=data, x='low_fat', palette='Paired')
fig.show()

# %%
fig = plt.figure(figsize=(15,6))
sns.histplot(data=data, x='units_per_case', kde=True, color='#E74C3C')
fig.show()

# %%
plt.figure(figsize=(18,12))
sns.heatmap(data.corr(), annot=True)
plt.show()
