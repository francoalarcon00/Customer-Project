# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('clean_data.csv')
data
# Out:
#        index    food_category food_department     food_family  store_sales  \
# 0          0  Breakfast Foods    Frozen Foods            Food         7.36
# 1          1  Breakfast Foods    Frozen Foods            Food         5.52
# 2          2  Breakfast Foods    Frozen Foods            Food         3.68
# 3          3  Breakfast Foods    Frozen Foods            Food         3.68
# 4          4  Breakfast Foods    Frozen Foods            Food         4.08
# ...      ...              ...             ...             ...          ...
# 60423  60423        Specialty        Carousel  Non-Consumable         2.76
# 60424  60424        Specialty        Carousel  Non-Consumable         1.60
# 60425  60425        Specialty        Carousel  Non-Consumable         5.52
# 60426  60426        Specialty        Carousel  Non-Consumable         8.28
# 60427  60427        Specialty        Carousel  Non-Consumable         9.20
#
# ...

# %%
data = data.drop('index', axis=1)

# %%
data.columns
# Out:
# Index(['food_category', 'food_department', 'food_family', 'store_sales',
#        'store_cost', 'unit_sales', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at_home',
#        'avg_yearly_income', 'num_children_at_home', 'avg_cars_at_home1',
#        'brand_name', 'SRP', 'gross_weight', 'net_weight', 'recyclable_package',
#        'low_fat', 'units_per_case', 'store_type', 'store_city', 'store_state',
#        'store_sqft', 'grocery_sqft', 'frozen_sqft', 'meat_sqft', 'coffee_bar',
#        'video_store', 'salad_bar', 'prepared_food', 'florist', 'media_type',
#        'cost'],
#       dtype='object')

# %%
sns.set_style('darkgrid')

# %%
# Food category
plt.figure(figsize=(20,20))
sns.countplot(data=data, y='food_category', palette='tab20b')
plt.show()
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='food_category', y='cost', palette='tab20b')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# Food department
plt.figure(figsize=(20,20))
sns.countplot(data=data, y='food_department', palette='rainbow')
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='food_department', y='cost', palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# Food family
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='food_family', palette='summer')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='food_family', y='cost', palette='summer')
plt.show()

# %%
#Store sales
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='store_sales', kde=True, color='#1ABC9C')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='store_sales', color='#1ABC9C')
plt.show()

# %%
# Store cost
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='store_cost', kde=True, color='#C832D6')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='store_cost', color='#C832D6')
plt.show()

# %%
# Unit sales
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='unit_sales', palette='rocket')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='unit_sales', y='cost', palette='rocket')
plt.show()

# %%
# Promotion name
plt.figure(figsize=(20,20))
sns.countplot(data=data, y='promotion_name', palette='tab20c')
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='promotion_name', y='cost', palette='tab20c')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# Sales country
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='sales_country', palette='cividis')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='sales_country', y='cost', palette='cividis')
plt.show()

# %%
# Marital Status
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='marital_status', palette='viridis')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='marital_status', y='cost', palette='viridis')
plt.show()

# %%
# Gender
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='gender', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='gender', y='cost', color='dodgerblue')
plt.show()

# %%
# Total children
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='total_children', palette='gnuplot2')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='total_children', y='cost', palette='gnuplot2')
plt.show()

# %%
# Education
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='education', palette='rocket')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='education', y='cost', palette='rocket')
plt.show()

# %%
# Member card
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='member_card', palette='ocean')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='member_card', y='cost', palette='ocean')
plt.show()

# %%
# Occupation
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='occupation', palette='terrain')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='occupation', y='cost', palette='terrain')
plt.show()

# %%
# House owner
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='houseowner', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='houseowner', y='cost', color='dodgerblue')
plt.show()

# %%
# Average cars at home
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='avg_cars_at_home', palette='Set2')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='avg_cars_at_home', y='cost', palette='Set2')
plt.show()

# %%
# Avgerage early income
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='avg_yearly_income', palette='Set1')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='avg_yearly_income', y='cost', palette='Set1')
plt.show()

# %%
# Number of children at home
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='num_children_at_home', palette='rocket')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='num_children_at_home', y='cost', palette='rocket')
plt.show()

# %%
# Brand name
plt.figure(figsize=(20,23))
sns.countplot(data=data, y='brand_name', palette='rainbow')
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='brand_name', y='cost', palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# SRP
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='SRP', kde=True, color='#34495E')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='SRP', color='#34495E')
plt.show()

# %%
# Gross weight
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='gross_weight', kde=True, color='#F39C12')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='gross_weight', color='#F39C12')
plt.show()

# %%
# Net weight
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='net_weight', kde=True, color='crimson')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='net_weight', color='crimson')
plt.show()

# %%
# Recyclable package
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='recyclable_package', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='recyclable_package', y='cost', color='dodgerblue')
plt.show()

# %%
# Low fat
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='low_fat', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='low_fat', y='cost', color='dodgerblue')
plt.show()

# %%
# Units per case
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='units_per_case', kde=True, color='#E74C3C')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='units_per_case', color='#E74C3C')
plt.show()

# %%
# Store type
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='store_type', palette='Paired')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='store_type', y='cost', palette='Paired')
plt.show()

# %%
# Store city
plt.figure(figsize=(20,8))
sns.countplot(data=data, x='store_city', palette='tab20c')
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='store_city', y='cost', palette='tab20c')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# Store state
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='store_state', palette='rocket')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='store_state', y='cost', palette='rocket')
plt.show()

# %%
# Store sqft
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='store_sqft', palette='hot')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='store_sqft', y='cost', palette='hot')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='grocery_sqft', palette='coolwarm')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='grocery_sqft', y='cost', palette='coolwarm')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='frozen_sqft', palette='RdYlGn')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='frozen_sqft', y='cost', palette='RdYlGn')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='coffee_bar', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='coffee_bar', y='cost', color='dodgerblue')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='video_store', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='video_store', y='cost', color='dodgerblue')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='salad_bar', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='salad_bar', y='cost', color='dodgerblue')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='prepared_food', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='prepared_food', y='cost', color='dodgerblue')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.countplot(data=data, x='florist', color='dodgerblue')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='florist', y='cost', color='dodgerblue')
plt.show()

# %%
# Media type
plt.figure(figsize=(20,8))
ax = sns.countplot(data=data, x='media_type', palette='rocket')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.figure(figsize=(20,10))
ax = sns.boxplot(data=data, x='media_type', y='cost', palette='rocket')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# Units per case
plt.figure(figsize=(20,15))
plt.subplot(2,1,1)
sns.histplot(data=data, x='cost', kde=True, color='#E74C3C')
plt.subplot(2,1,2)
sns.boxplot(data=data, x='cost', color='#E74C3C')
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.heatmap(data.corr(), annot=True)
plt.show()
